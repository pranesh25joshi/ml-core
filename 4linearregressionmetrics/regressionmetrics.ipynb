# %%
import numpy as np;
import pandas as pd

# %%
df = pd.read_csv('placement.csv');
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x = df.iloc[:, [0]].values
x
y = df.iloc[:, [1]].values
type(y)
x.size
# Out:
# 200

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=2, test_size=0.2)
x_train.shape
# Out:
# (160, 1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.xlabel("cgpa")
plt.ylabel("lpa")
# therefore linear regression can be performed
# Out:
# Text(0, 0.5, 'lpa')

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score
y_pre = lr.predict(x_test)

# %%
y_test
# Out:
# array([[4.1 ],
#        [3.49],
#        [2.08],
#        [2.33],
#        [1.94],
#        [1.48],
#        [1.86],
#        [3.09],
#        [4.21],
#        [2.87],
#        [3.65],
#        [4.  ],
#        [2.89],
#        [2.6 ],
#        [2.99],
#        [3.25],
#        [1.86],
#        [3.67],
#        [2.37],
#        [3.42],
#        [2.48],
#        [3.65],
#        [2.6 ],
#        [2.83],
#        [4.08],
#        [2.56],
#        [3.58],
#        [3.81],
#        [4.09],
#        [2.01],
#        [3.63],
#        [2.92],
#        [3.51],
#        [1.94],
#        [2.21],
#        [3.34],
#        [3.34],
#        [3.23],
#        [2.01],
#        [2.61]])

# %%
mean_absolute_error(y_test, y_pre)
# Out:
# 0.2884710931878175

# %%
mean_squared_error(y_test, y_pre)
# Out:
# 0.12129235313495527

# %%
root_mean_squared_error(x_test, y_pre)
# Out:
# 4.015444735310167

# %%
r2_scoree = r2_score(y_test, y_pre)
r2_scoree
# Out:
# 0.780730147510384

# %%
adjusted_r2_score = 1- ((1-r2_scoree)*(40 -1)/(40-1-1))
adjusted_r2_score
# Out:
# 0.7749598882343415
